# %%
import pandas as pd

# %%
df = pd.read_csv("store.csv")

# %%
df
# Out:
#       Unnamed: 0          id  \
# 0              1   281656475
# 1              2   281796108
# 2              3   281940292
# 3              4   282614216
# 4              5   282935706
# ...          ...         ...
# 7192       11081  1187617475
# 7193       11082  1187682390
# 7194       11087  1187779532
# 7195       11089  1187838770
# 7196       11097  1188375727
#
#                                              track_name  size_bytes currency  \
# 0                                       PAC-MAN Premium   100788224      USD
# 1                             Evernote - stay organized   158578688      USD
# 2       WeatherBug - Local Weather, Radar, Maps, Alerts   100524032      USD
# 3     eBay: Best App to Buy, Sell, Save! Online Shop...   128512000      USD
# 4                                                 Bible    92774400      USD
# ...                                                 ...         ...      ...
# ...

# %%
df.iloc[2]
# Out:
# Unnamed: 0                                                        3
# id                                                        281940292
# track_name          WeatherBug - Local Weather, Radar, Maps, Alerts
# size_bytes                                                100524032
# currency                                                        USD
# price                                                           0.0
# rating_count_tot                                             188583
# rating_count_ver                                               2822
# user_rating                                                     3.5
# user_rating_ver                                                 4.5
# ver                                                           5.0.0
# cont_rating                                                      4+
# prime_genre                                                 Weather
# sup_devices.num                                                  37
# ...

# %%
print(df)
# Out:
#       Unnamed: 0          id  \
# 0              1   281656475
# 1              2   281796108
# 2              3   281940292
# 3              4   282614216
# 4              5   282935706
# ...          ...         ...
# 7192       11081  1187617475
# 7193       11082  1187682390
# 7194       11087  1187779532
# 7195       11089  1187838770
# 7196       11097  1188375727
#
#                                              track_name  size_bytes currency  \
# 0                                       PAC-MAN Premium   100788224      USD
# 1                             Evernote - stay organized   158578688      USD
# 2       WeatherBug - Local Weather, Radar, Maps, Alerts   100524032      USD
# 3     eBay: Best App to Buy, Sell, Save! Online Shop...   128512000      USD
# 4                                                 Bible    92774400      USD
# ...                                                 ...         ...      ...
# ...

# %%
print(df.iloc[:2])
# Out:
#    Unnamed: 0         id                 track_name  size_bytes currency  \
# 0           1  281656475            PAC-MAN Premium   100788224      USD
# 1           2  281796108  Evernote - stay organized   158578688      USD
#
#    price  rating_count_tot  rating_count_ver  user_rating  user_rating_ver  \
# 0   3.99             21292                26          4.0              4.5
# 1   0.00            161065                26          4.0              3.5
#
#      ver cont_rating   prime_genre  sup_devices.num  ipadSc_urls.num  \
# 0  6.3.5          4+         Games               38                5
# 1  8.2.2          4+  Productivity               37                5
#
#    lang.num  vpp_lic
# 0        10        1
# 1        23        1

# %%
df.isnull()
# Out:
#       Unnamed: 0     id  track_name  size_bytes  currency  price  \
# 0          False  False       False       False     False  False
# 1          False  False       False       False     False  False
# 2          False  False       False       False     False  False
# 3          False  False       False       False     False  False
# 4          False  False       False       False     False  False
# ...          ...    ...         ...         ...       ...    ...
# 7192       False  False       False       False     False  False
# 7193       False  False       False       False     False  False
# 7194       False  False       False       False     False  False
# 7195       False  False       False       False     False  False
# 7196       False  False       False       False     False  False
#
#       rating_count_tot  rating_count_ver  user_rating  user_rating_ver    ver  \
# 0                False             False        False            False  False
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# id                  0
# track_name          0
# size_bytes          0
# currency            0
# price               0
# rating_count_tot    0
# rating_count_ver    0
# user_rating         0
# user_rating_ver     0
# ver                 0
# cont_rating         0
# prime_genre         0
# sup_devices.num     0
# ipadSc_urls.num     0
# lang.num            0
# vpp_lic             0
# dtype: int64

# %%
df.notnull().sum()
# Out:
# Unnamed: 0          7197
# id                  7197
# track_name          7197
# size_bytes          7197
# currency            7197
# price               7197
# rating_count_tot    7197
# rating_count_ver    7197
# user_rating         7197
# user_rating_ver     7197
# ver                 7197
# cont_rating         7197
# prime_genre         7197
# sup_devices.num     7197
# ipadSc_urls.num     7197
# lang.num            7197
# vpp_lic             7197
# dtype: int64

# %%
df.head()
# Out:
#    Unnamed: 0         id                                         track_name  \
# 0           1  281656475                                    PAC-MAN Premium
# 1           2  281796108                          Evernote - stay organized
# 2           3  281940292    WeatherBug - Local Weather, Radar, Maps, Alerts
# 3           4  282614216  eBay: Best App to Buy, Sell, Save! Online Shop...
# 4           5  282935706                                              Bible
#
#    size_bytes currency  price  rating_count_tot  rating_count_ver  \
# 0   100788224      USD   3.99             21292                26
# 1   158578688      USD   0.00            161065                26
# 2   100524032      USD   0.00            188583              2822
# 3   128512000      USD   0.00            262241               649
# 4    92774400      USD   0.00            985920              5320
#
#    user_rating  user_rating_ver     ver cont_rating   prime_genre  \
# ...

# %%
df.loc[[0,1], :]
# Out:
#    Unnamed: 0         id                 track_name  size_bytes currency  \
# 0           1  281656475            PAC-MAN Premium   100788224      USD
# 1           2  281796108  Evernote - stay organized   158578688      USD
#
#    price  rating_count_tot  rating_count_ver  user_rating  user_rating_ver  \
# 0   3.99             21292                26          4.0              4.5
# 1   0.00            161065                26          4.0              3.5
#
#      ver cont_rating   prime_genre  sup_devices.num  ipadSc_urls.num  \
# 0  6.3.5          4+         Games               38                5
# 1  8.2.2          4+  Productivity               37                5
#
#    lang.num  vpp_lic
# 0        10        1
# 1        23        1

# %%
df['track_name'].value_counts()
# Out:
# VR Roller Coaster                                   2
# Mannequin Challenge                                 2
# PAC-MAN Premium                                     1
# European Qualifiers Official App                    1
# Tooth Fairy Princess - Magical Adventure            1
#                                                    ..
# Heart of Vegas Slots – Casino Slot Machine Games    1
# 赤ペン 提出カメラ                                           1
# J&J Official 7 Minute Workout                       1
# Beautiful Japanese Handwriting                      1
# Escape the Sweet Shop Series                        1
# Name: track_name, Length: 7195, dtype: int64

# %%
df['user_rating'].value_counts()
# Out:
# 4.5    2663
# 4.0    1626
# 0.0     929
# 3.5     702
# 5.0     492
# 3.0     383
# 2.5     196
# 2.0     106
# 1.5      56
# 1.0      44
# Name: user_rating, dtype: int64

# %%
df['lang.num'].value_counts()
# Out:
# 1     3767
# 2      675
# 11     266
# 3      217
# 5      207
# 12     179
# 10     168
# 4      154
# 8      145
# 6      143
# 9      138
# 7      133
# 13     130
# 16     114
# 14      89
# 15      86
# 18      71
# 31      53
# 17      46
# 0       41
# 21      35
# 22      32
# 33      30
# 19      30
# 30      28
# 23      24
# 26      22
# 20      21
# 29      20
# 32      17
# 24      16
# 25      14
# 34      13
# 58      12
# 45       9
# 28       8
# 27       7
# 36       4
# 46       4
# 42       3
# 69       3
# 35       2
# 37       2
# 41       2
# 55       2
# 39       2
# 54       2
# 43       2
# 63       1
# 68       1
# 50       1
# 75       1
# 40       1
# 47       1
# 56       1
# 59       1
# 74       1
# Name: lang.num, dtype: int64

# %%
df['vpp_lic'].value_counts()
# Out:
# 1    7147
# 0      50
# Name: vpp_lic, dtype: int64

# %%
df['ipadSc_urls.num'].value_counts()
# Out:
# 5    4503
# 0    1387
# 4     710
# 3     286
# 2     156
# 1     155
# Name: ipadSc_urls.num, dtype: int64

# %%
df['sup_devices.num'].value_counts()
# Out:
# 37    3263
# 38    1912
# 40    1142
# 43     371
# 24     270
# 25      67
# 26      42
# 39      40
# 47      26
# 35      24
# 45       8
# 16       8
# 36       7
# 13       7
# 11       3
# 15       2
# 33       2
# 12       1
# 23       1
# 9        1
# Name: sup_devices.num, dtype: int64

# %%
df['prime_genre'].value_counts()
# Out:
# Games                3862
# Entertainment         535
# Education             453
# Photo & Video         349
# Utilities             248
# Health & Fitness      180
# Productivity          178
# Social Networking     167
# Lifestyle             144
# Music                 138
# Shopping              122
# Sports                114
# Book                  112
# Finance               104
# Travel                 81
# News                   75
# Weather                72
# Reference              64
# Food & Drink           63
# Business               57
# Navigation             46
# Medical                23
# Catalogs               10
# Name: prime_genre, dtype: int64

# %%
df['cont_rating'].value_counts()
# Out:
# 4+     4433
# 12+    1155
# 9+      987
# 17+     622
# Name: cont_rating, dtype: int64

# %%
df['ver'].value_counts()
# Out:
# 1           322
# 1.1         282
# 1.2         221
# 1.0.0       187
# 1.0.1       180
#            ...
# 1.7.7.78      1
# 8.0.5         1
# 4.33.3        1
# 3.7.3         1
# 2.0.20.1      1
# Name: ver, Length: 1546, dtype: int64

# %%
df['user_rating_ver'].value_counts()
# Out:
# 4.5    2205
# 0.0    1443
# 4.0    1237
# 5.0     964
# 3.5     533
# 3.0     304
# 2.5     176
# 2.0     136
# 1.0     125
# 1.5      74
# Name: user_rating_ver, dtype: int64

# %%
df['rating_count_ver'].value_counts()
# Out:
# 0        1443
# 1         379
# 2         204
# 3         182
# 4         151
#          ...
# 22200       1
# 1160        1
# 1655        1
# 464         1
# 1441        1
# Name: rating_count_ver, Length: 1138, dtype: int64

# %%
df['rating_count_tot'].value_counts()
# Out:
# 0         929
# 1         120
# 7          48
# 9          47
# 5          46
#          ...
# 1155        1
# 7131        1
# 416736      1
# 40531       1
# 1441        1
# Name: rating_count_tot, Length: 3185, dtype: int64

# %%
df['price'].value_counts()
# Out:
# 0.00      4056
# 0.99       728
# 2.99       683
# 1.99       621
# 4.99       394
# 3.99       277
# 6.99       166
# 9.99        81
# 5.99        52
# 7.99        33
# 14.99       21
# 19.99       13
# 8.99         9
# 24.99        8
# 29.99        6
# 13.99        6
# 11.99        6
# 12.99        5
# 15.99        4
# 17.99        3
# 59.99        3
# 39.99        2
# 20.99        2
# 23.99        2
# 49.99        2
# 22.99        2
# 27.99        2
# 16.99        2
# 299.99       1
# 21.99        1
# 47.99        1
# 99.99        1
# 74.99        1
# 34.99        1
# 18.99        1
# 249.99       1
# Name: price, dtype: int64

# %%
df['currency'].value_counts()
# Out:
# USD    7197
# Name: currency, dtype: int64

# %%
df['size_bytes'].value_counts()
# Out:
# 31624192      3
# 137094144     2
# 34856960      2
# 270729216     2
# 96497664      2
#              ..
# 1676402688    1
# 918957056     1
# 793368576     1
# 56655872      1
# 90898432      1
# Name: size_bytes, Length: 7107, dtype: int64

# %%
df['id'].value_counts()
# Out:
# 281656475     1
# 1058526204    1
# 1061661355    1
# 1061610336    1
# 1061572575    1
#              ..
# 785638228     1
# 785537179     1
# 785267899     1
# 784797900     1
# 1188375727    1
# Name: id, Length: 7197, dtype: int64

# %%
df['Unnamed: 0'].value_counts()
# Out:
# 1        1
# 6071     1
# 6208     1
# 6207     1
# 6206     1
#         ..
# 2813     1
# 2812     1
# 2811     1
# 2809     1
# 11097    1
# Name: Unnamed: 0, Length: 7197, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7197 entries, 0 to 7196
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        7197 non-null   int64
#  1   id                7197 non-null   int64
#  2   track_name        7197 non-null   object
#  3   size_bytes        7197 non-null   int64
#  4   currency          7197 non-null   object
#  5   price             7197 non-null   float64
#  6   rating_count_tot  7197 non-null   int64
#  7   rating_count_ver  7197 non-null   int64
#  8   user_rating       7197 non-null   float64
#  9   user_rating_ver   7197 non-null   float64
#  10  ver               7197 non-null   object
#  11  cont_rating       7197 non-null   object
#  12  prime_genre       7197 non-null   object
#  13  sup_devices.num   7197 non-null   int64
#  14  ipadSc_urls.num   7197 non-null   int64
#  15  lang.num          7197 non-null   int64
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.user_rating.duplicated()
# Out:
# 0       False
# 1        True
# 2       False
# 3        True
# 4       False
#         ...
# 7192     True
# 7193     True
# 7194     True
# 7195     True
# 7196     True
# Name: user_rating, Length: 7197, dtype: bool

# %%
df.track_name.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7192    False
# 7193    False
# 7194    False
# 7195    False
# 7196    False
# Name: track_name, Length: 7197, dtype: bool

# %%
df.prime_genre.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7192     True
# 7193     True
# 7194     True
# 7195     True
# 7196     True
# Name: prime_genre, Length: 7197, dtype: bool

# %%
df.drop_duplicates()
# Out:
#       Unnamed: 0          id  \
# 0              1   281656475
# 1              2   281796108
# 2              3   281940292
# 3              4   282614216
# 4              5   282935706
# ...          ...         ...
# 7192       11081  1187617475
# 7193       11082  1187682390
# 7194       11087  1187779532
# 7195       11089  1187838770
# 7196       11097  1188375727
#
#                                              track_name  size_bytes currency  \
# 0                                       PAC-MAN Premium   100788224      USD
# 1                             Evernote - stay organized   158578688      USD
# 2       WeatherBug - Local Weather, Radar, Maps, Alerts   100524032      USD
# 3     eBay: Best App to Buy, Sell, Save! Online Shop...   128512000      USD
# 4                                                 Bible    92774400      USD
# ...                                                 ...         ...      ...
# ...

# %%
df.drop_duplicates(subset=['track_name'])
# Out:
#       Unnamed: 0          id  \
# 0              1   281656475
# 1              2   281796108
# 2              3   281940292
# 3              4   282614216
# 4              5   282935706
# ...          ...         ...
# 7192       11081  1187617475
# 7193       11082  1187682390
# 7194       11087  1187779532
# 7195       11089  1187838770
# 7196       11097  1188375727
#
#                                              track_name  size_bytes currency  \
# 0                                       PAC-MAN Premium   100788224      USD
# 1                             Evernote - stay organized   158578688      USD
# 2       WeatherBug - Local Weather, Radar, Maps, Alerts   100524032      USD
# 3     eBay: Best App to Buy, Sell, Save! Online Shop...   128512000      USD
# 4                                                 Bible    92774400      USD
# ...                                                 ...         ...      ...
# ...

# %%
df.drop_duplicates(subset=['user_rating'])
# Out:
#      Unnamed: 0         id                                       track_name  \
# 0             1  281656475                                  PAC-MAN Premium
# 2             3  281940292  WeatherBug - Local Weather, Radar, Maps, Alerts
# 4             5  282935706                                            Bible
# 21           23  285994151                                      :) Sudoku +
# 26           29  286911400                                         Hangman.
# 86           99  303849934                                   Beer Pong Game
# 97          110  306375551                                       Wind Meter
# 199         227  329174056                     iLoan Calc (Loan calculator)
# 402         458  369970819                           Fake-A-Location Free ™
# 639         734  409299054                           SecurityCam for iPhone
#
#      size_bytes currency  price  rating_count_tot  rating_count_ver  \
# ...

# %%
df.drop_duplicates(subset=['price', 'cont_rating'])
# Out:
#       Unnamed: 0          id  \
# 0              1   281656475
# 1              2   281796108
# 3              4   282614216
# 5              6   283619399
# 8              9   284666222
# ...          ...         ...
# 4662        5974  1055636344
# 4739        6096  1059218666
# 5426        7272  1083835330
# 5668        7702  1092448381
# 6709        9917  1142443107
#
#                                              track_name  size_bytes currency  \
# 0                                       PAC-MAN Premium   100788224      USD
# 1                             Evernote - stay organized   158578688      USD
# 3     eBay: Best App to Buy, Sell, Save! Online Shop...   128512000      USD
# 5                                      Shanghai Mahjong    10485713      USD
# 8                           PCalc - The Best Calculator    49250304      USD
# ...                                                 ...         ...      ...
# ...

# %%
df.drop_duplicates(subset=['size_bytes','prime_genre'])
# Out:
#       Unnamed: 0          id  \
# 0              1   281656475
# 1              2   281796108
# 2              3   281940292
# 3              4   282614216
# 4              5   282935706
# ...          ...         ...
# 7192       11081  1187617475
# 7193       11082  1187682390
# 7194       11087  1187779532
# 7195       11089  1187838770
# 7196       11097  1188375727
#
#                                              track_name  size_bytes currency  \
# 0                                       PAC-MAN Premium   100788224      USD
# 1                             Evernote - stay organized   158578688      USD
# 2       WeatherBug - Local Weather, Radar, Maps, Alerts   100524032      USD
# 3     eBay: Best App to Buy, Sell, Save! Online Shop...   128512000      USD
# 4                                                 Bible    92774400      USD
# ...                                                 ...         ...      ...
# ...

# %%
df.drop_duplicates(subset=['lang.num'])
# Out:
#       Unnamed: 0          id  \
# 0              1   281656475
# 1              2   281796108
# 2              3   281940292
# 3              4   282614216
# 4              5   282935706
# 5              6   283619399
# 6              7   283646709
# 10            11   284791396
# 11            12   284815117
# 12            13   284815942
# 13            14   284847138
# 15            16   284876795
# 16            17   284882215
# 17            18   284910350
# 18            20   284993459
# 31            35   289084315
# 33            37   289523017
# 41            49   292738169
# 43            51   293523031
# 44            52   293573778
# 45            53   293622097
# 50            59   294631159
# 62            71   297606951
# 63            72   297694601
# 66            75   298596830
# 72            82   300048137
# 77            87   300704847
# 91           104   304878510
# 123          138   309735670
# 125          140   310633997
# 131          150   311762416
# ...

# %%
df.drop_duplicates(subset=['id','size_bytes','rating_count_tot'])
# Out:
#       Unnamed: 0          id  \
# 0              1   281656475
# 1              2   281796108
# 2              3   281940292
# 3              4   282614216
# 4              5   282935706
# ...          ...         ...
# 7192       11081  1187617475
# 7193       11082  1187682390
# 7194       11087  1187779532
# 7195       11089  1187838770
# 7196       11097  1188375727
#
#                                              track_name  size_bytes currency  \
# 0                                       PAC-MAN Premium   100788224      USD
# 1                             Evernote - stay organized   158578688      USD
# 2       WeatherBug - Local Weather, Radar, Maps, Alerts   100524032      USD
# 3     eBay: Best App to Buy, Sell, Save! Online Shop...   128512000      USD
# 4                                                 Bible    92774400      USD
# ...                                                 ...         ...      ...
# ...

# %%
df.drop_duplicates(subset=['ver','rating_count_ver'])
# Out:
#       Unnamed: 0          id  \
# 0              1   281656475
# 1              2   281796108
# 2              3   281940292
# 3              4   282614216
# 4              5   282935706
# ...          ...         ...
# 7183       11041  1185580782
# 7190       11077  1187279979
# 7192       11081  1187617475
# 7193       11082  1187682390
# 7195       11089  1187838770
#
#                                              track_name  size_bytes currency  \
# 0                                       PAC-MAN Premium   100788224      USD
# 1                             Evernote - stay organized   158578688      USD
# 2       WeatherBug - Local Weather, Radar, Maps, Alerts   100524032      USD
# 3     eBay: Best App to Buy, Sell, Save! Online Shop...   128512000      USD
# 4                                                 Bible    92774400      USD
# ...                                                 ...         ...      ...
# ...

# %%
df.drop_duplicates(subset=['user_rating_ver'])
# Out:
#      Unnamed: 0         id                                 track_name  \
# 0             1  281656475                            PAC-MAN Premium
# 1             2  281796108                  Evernote - stay organized
# 4             5  282935706                                      Bible
# 5             6  283619399                           Shanghai Mahjong
# 11           12  284815117                           SCRABBLE Premium
# 23           25  286070473                  Mileage Log | Fahrtenbuch
# 35           40  290638154  iHeartRadio – Free Music & Radio Stations
# 60           69  297430070                                     Target
# 70           80  299853944                        新浪新闻-阅读最新时事热门头条资讯视频
# 200         228  329541503                                Geocaching®
#
#      size_bytes currency  price  rating_count_tot  rating_count_ver  \
# 0     100788224      USD   3.99             21292                26
# ...

# %%
df.drop_duplicates(subset=['vpp_lic'])
# Out:
#     Unnamed: 0         id       track_name  size_bytes currency  price  \
# 0            1  281656475  PAC-MAN Premium   100788224      USD   3.99
# 42          50  293118835         iStellar    44241920      USD   3.99
#
#     rating_count_tot  rating_count_ver  user_rating  user_rating_ver    ver  \
# 0              21292                26          4.0              4.5  6.3.5
# 42                30                 0          3.5              0.0  2.9.0
#
#    cont_rating prime_genre  sup_devices.num  ipadSc_urls.num  lang.num  \
# 0           4+       Games               38                5        10
# 42          4+  Navigation               37                0         2
#
#     vpp_lic
# 0         1
# 42        0

# %%
df.drop_duplicates(subset=['ipadSc_urls.num'])
# Out:
#     Unnamed: 0         id                                         track_name  \
# 0            1  281656475                                    PAC-MAN Premium
# 6            7  283646709             PayPal - Send and request money safely
# 7            8  284035177                            Pandora - Music & Radio
# 15          16  284876795             TripAdvisor Hotels Flights Restaurants
# 18          20  284993459  Shazam - Discover music, artists, videos & lyrics
# 22          24  286058814    Yahoo Sports - Teams, Scores, News & Highlights
#
#     size_bytes currency  price  rating_count_tot  rating_count_ver  \
# 0    100788224      USD   3.99             21292                26
# 6    227795968      USD   0.00            119487               879
# 7    130242560      USD   0.00           1126879              3594
# 15   207907840      USD   0.00             56194                87
# 18   147093504      USD   0.00            402925               136
# ...

# %%
df.drop_duplicates(subset=['sup_devices.num'])
# Out:
#       Unnamed: 0          id                                     track_name  \
# 0              1   281656475                                PAC-MAN Premium
# 1              2   281796108                      Evernote - stay organized
# 5              6   283619399                               Shanghai Mahjong
# 20            22   285946052                                         iQuran
# 21            23   285994151                                    :) Sudoku +
# 125          140   310633997                             WhatsApp Messenger
# 155          177   318639200                               Crush the Castle
# 341          383   358207332                                    Drawing Pad
# 362          408   364017607     ArtStudio for iPad - Draw Sketch and Paint
# 441          503   377321278                                        恵方コンパス.
# 1315        1527   525176875   Sun Surveyor - Sun & Moon Visualization Tool
# ...

# %%
df.drop_duplicates(subset=['track_name']).shape
# Out:
# (7195, 17)

# %%
df.drop_duplicates(subset=['user_rating']).shape
# Out:
# (10, 17)

# %%
df.drop_duplicates(subset=['prime_genre']).shape
# Out:
# (23, 17)

# %%
df.drop_duplicates(subset=['lang.num']).shape
# Out:
# (57, 17)

# %%
df.drop_duplicates(subset=['cont_rating']).shape
# Out:
# (4, 17)

# %%
df.drop_duplicates(subset=['price']).shape
# Out:
# (36, 17)

# %%
df.drop_duplicates(subset=['currency']).shape
# Out:
# (1, 17)

# %%
df.drop_duplicates(subset=['ver']).shape
# Out:
# (1546, 17)

# %%
df.drop_duplicates(subset=['rating_count_tot']).shape
# Out:
# (3185, 17)

# %%
df.drop_duplicates(subset=['rating_count_ver']).shape
# Out:
# (1138, 17)

# %%
df.drop_duplicates(subset=['user_rating_ver']).shape
# Out:
# (10, 17)

# %%
df.drop_duplicates(subset=['sup_devices.num']).shape
# Out:
# (20, 17)

# %%
df.drop_duplicates(subset=['ipadSc_urls.num']).shape
# Out:
# (6, 17)

# %%
df.drop_duplicates(subset=['vpp_lic']).shape
# Out:
# (2, 17)

# %%
df.drop_duplicates(subset=['currency'])
# Out:
#    Unnamed: 0         id       track_name  size_bytes currency  price  \
# 0           1  281656475  PAC-MAN Premium   100788224      USD   3.99
#
#    rating_count_tot  rating_count_ver  user_rating  user_rating_ver    ver  \
# 0             21292                26          4.0              4.5  6.3.5
#
#   cont_rating prime_genre  sup_devices.num  ipadSc_urls.num  lang.num  vpp_lic
# 0          4+       Games               38                5        10        1

# %%
df.drop_duplicates(subset=['user_rating','price'], keep=False, inplace=True)

# %%
df
# Out:
#       Unnamed: 0          id  \
# 65            74   298206806
# 68            77   299029654
# 115          129   308368164
# 162          184   320279293
# 352          398   363317633
# 778          887   432278816
# 785          896   432850619
# 812          924   436577167
# 1188        1385   502803489
# 1439        1668   544695089
# 1479        1714   551215116
# 1498        1738   554245373
# 1688        1963   583976519
# 1714        1991   586803362
# 1754        2036   593042008
# 2099        2442   674590967
# 2208        2574   714463714
# 2405        2824   791077159
# 2568        3043   849732663
# 2744        3272   890358046
# 2949        3523   914189520
# 3012        3596   920133658
# 3093        3706   932191687
# 3238        3899   946930094
# 4084        5083  1021566244
# 4096        5099  1022100908
# 4387        5548  1041260001
# 4388        5549  1041317729
# 4391        5555  1041465860
# 4599        5871  1052650787
# 4651        5961  1055359142
# ...

# %%
df.drop_duplicates(subset=['track_name','prime_genre'], keep=False, inplace=True)
df
# Out:
#       Unnamed: 0          id  \
# 65            74   298206806
# 68            77   299029654
# 115          129   308368164
# 162          184   320279293
# 352          398   363317633
# 778          887   432278816
# 785          896   432850619
# 812          924   436577167
# 1188        1385   502803489
# 1439        1668   544695089
# 1479        1714   551215116
# 1498        1738   554245373
# 1688        1963   583976519
# 1714        1991   586803362
# 1754        2036   593042008
# 2099        2442   674590967
# 2208        2574   714463714
# 2405        2824   791077159
# 2568        3043   849732663
# 2744        3272   890358046
# 2949        3523   914189520
# 3012        3596   920133658
# 3093        3706   932191687
# 3238        3899   946930094
# 4084        5083  1021566244
# 4096        5099  1022100908
# 4387        5548  1041260001
# 4388        5549  1041317729
# 4391        5555  1041465860
# 4599        5871  1052650787
# 4651        5961  1055359142
# ...

# %%
def is_it_english(string_name):
    non_ascii = 0
    for character in string_name:
        if ord(character) > 127:
            non_ascii =+ 1
    if non_ascii > 3:
        return False
    else:
        return True

# %%
is_english_list = []
for i in df["track_name"]:
       is_english_list.append(is_it_english(i))
print(is_english_list)
# Out:
# [True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True]

# %%
set(is_english_list)
# Out:
# {True}

# %%
df["is_english"] = is_english_list

# %%
df
# Out:
#       Unnamed: 0          id  \
# 65            74   298206806
# 68            77   299029654
# 115          129   308368164
# 162          184   320279293
# 352          398   363317633
# 778          887   432278816
# 785          896   432850619
# 812          924   436577167
# 1188        1385   502803489
# 1439        1668   544695089
# 1479        1714   551215116
# 1498        1738   554245373
# 1688        1963   583976519
# 1714        1991   586803362
# 1754        2036   593042008
# 2099        2442   674590967
# 2208        2574   714463714
# 2405        2824   791077159
# 2568        3043   849732663
# 2744        3272   890358046
# 2949        3523   914189520
# 3012        3596   920133658
# 3093        3706   932191687
# 3238        3899   946930094
# 4084        5083  1021566244
# 4096        5099  1022100908
# 4387        5548  1041260001
# 4388        5549  1041317729
# 4391        5555  1041465860
# 4599        5871  1052650787
# 4651        5961  1055359142
# ...

# %%
print(df)
# Out:
#       Unnamed: 0          id  \
# 65            74   298206806
# 68            77   299029654
# 115          129   308368164
# 162          184   320279293
# 352          398   363317633
# 778          887   432278816
# 785          896   432850619
# 812          924   436577167
# 1188        1385   502803489
# 1439        1668   544695089
# 1479        1714   551215116
# 1498        1738   554245373
# 1688        1963   583976519
# 1714        1991   586803362
# 1754        2036   593042008
# 2099        2442   674590967
# 2208        2574   714463714
# 2405        2824   791077159
# 2568        3043   849732663
# 2744        3272   890358046
# 2949        3523   914189520
# 3012        3596   920133658
# 3093        3706   932191687
# 3238        3899   946930094
# 4084        5083  1021566244
# 4096        5099  1022100908
# 4387        5548  1041260001
# 4388        5549  1041317729
# 4391        5555  1041465860
# 4599        5871  1052650787
# 4651        5961  1055359142
# ...

# %%
eng_df = df[df["is_english"]==True]

# %%
print(eng_df)
# Out:
#       Unnamed: 0          id  \
# 65            74   298206806
# 68            77   299029654
# 115          129   308368164
# 162          184   320279293
# 352          398   363317633
# 778          887   432278816
# 785          896   432850619
# 812          924   436577167
# 1188        1385   502803489
# 1439        1668   544695089
# 1479        1714   551215116
# 1498        1738   554245373
# 1688        1963   583976519
# 1714        1991   586803362
# 1754        2036   593042008
# 2099        2442   674590967
# 2208        2574   714463714
# 2405        2824   791077159
# 2568        3043   849732663
# 2744        3272   890358046
# 2949        3523   914189520
# 3012        3596   920133658
# 3093        3706   932191687
# 3238        3899   946930094
# 4084        5083  1021566244
# 4096        5099  1022100908
# 4387        5548  1041260001
# 4388        5549  1041317729
# 4391        5555  1041465860
# 4599        5871  1052650787
# 4651        5961  1055359142
# ...

# %%
eng_df
# Out:
#       Unnamed: 0          id  \
# 65            74   298206806
# 68            77   299029654
# 115          129   308368164
# 162          184   320279293
# 352          398   363317633
# 778          887   432278816
# 785          896   432850619
# 812          924   436577167
# 1188        1385   502803489
# 1439        1668   544695089
# 1479        1714   551215116
# 1498        1738   554245373
# 1688        1963   583976519
# 1714        1991   586803362
# 1754        2036   593042008
# 2099        2442   674590967
# 2208        2574   714463714
# 2405        2824   791077159
# 2568        3043   849732663
# 2744        3272   890358046
# 2949        3523   914189520
# 3012        3596   920133658
# 3093        3706   932191687
# 3238        3899   946930094
# 4084        5083  1021566244
# 4096        5099  1022100908
# 4387        5548  1041260001
# 4388        5549  1041317729
# 4391        5555  1041465860
# 4599        5871  1052650787
# 4651        5961  1055359142
# ...

# %%
df[df.track_name.map(lambda x:x.isascii())]
# Out:
#       Unnamed: 0          id  \
# 65            74   298206806
# 115          129   308368164
# 162          184   320279293
# 352          398   363317633
# 785          896   432850619
# 812          924   436577167
# 1439        1668   544695089
# 1479        1714   551215116
# 1498        1738   554245373
# 1688        1963   583976519
# 1754        2036   593042008
# 2208        2574   714463714
# 2405        2824   791077159
# 2568        3043   849732663
# 2744        3272   890358046
# 2949        3523   914189520
# 3012        3596   920133658
# 3093        3706   932191687
# 3238        3899   946930094
# 4084        5083  1021566244
# 4096        5099  1022100908
# 4388        5549  1041317729
# 4391        5555  1041465860
# 4599        5871  1052650787
# 4651        5961  1055359142
# 4662        5974  1055636344
# 4739        6096  1059218666
# 4879        6334  1064362767
# 5293        7038  1078412469
# 5340        7131  1080310524
# 5426        7272  1083835330
# ...

# %%
import pandas as pd
df = pd.read_csv("store.csv")
df
# Out:
#       Unnamed: 0          id  \
# 0              1   281656475
# 1              2   281796108
# 2              3   281940292
# 3              4   282614216
# 4              5   282935706
# ...          ...         ...
# 7192       11081  1187617475
# 7193       11082  1187682390
# 7194       11087  1187779532
# 7195       11089  1187838770
# 7196       11097  1188375727
#
#                                              track_name  size_bytes currency  \
# 0                                       PAC-MAN Premium   100788224      USD
# 1                             Evernote - stay organized   158578688      USD
# 2       WeatherBug - Local Weather, Radar, Maps, Alerts   100524032      USD
# 3     eBay: Best App to Buy, Sell, Save! Online Shop...   128512000      USD
# 4                                                 Bible    92774400      USD
# ...                                                 ...         ...      ...
# ...

# %%
def is_it_english(string_name):
    non_ascii = 0
    for character in string_name:
        if ord(character) > 127:
            non_ascii =+ 1
    if non_ascii > 3:
        return False
    else:
        return True

# %%
is_english_list = []
for i in df["track_name"]:
       is_english_list.append(is_it_english(i))
print(is_english_list)
# Out:
# [True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, T
# ...

# %%
set(is_english_list)
# Out:
# {True}

# %%
df["is_english"] = is_english_list

# %%
print(df)
# Out:
#       Unnamed: 0          id  \
# 0              1   281656475
# 1              2   281796108
# 2              3   281940292
# 3              4   282614216
# 4              5   282935706
# ...          ...         ...
# 7192       11081  1187617475
# 7193       11082  1187682390
# 7194       11087  1187779532
# 7195       11089  1187838770
# 7196       11097  1188375727
#
#                                              track_name  size_bytes currency  \
# 0                                       PAC-MAN Premium   100788224      USD
# 1                             Evernote - stay organized   158578688      USD
# 2       WeatherBug - Local Weather, Radar, Maps, Alerts   100524032      USD
# 3     eBay: Best App to Buy, Sell, Save! Online Shop...   128512000      USD
# 4                                                 Bible    92774400      USD
# ...                                                 ...         ...      ...
# ...

# %%
df
# Out:
#       Unnamed: 0          id  \
# 0              1   281656475
# 1              2   281796108
# 2              3   281940292
# 3              4   282614216
# 4              5   282935706
# ...          ...         ...
# 7192       11081  1187617475
# 7193       11082  1187682390
# 7194       11087  1187779532
# 7195       11089  1187838770
# 7196       11097  1188375727
#
#                                              track_name  size_bytes currency  \
# 0                                       PAC-MAN Premium   100788224      USD
# 1                             Evernote - stay organized   158578688      USD
# 2       WeatherBug - Local Weather, Radar, Maps, Alerts   100524032      USD
# 3     eBay: Best App to Buy, Sell, Save! Online Shop...   128512000      USD
# 4                                                 Bible    92774400      USD
# ...                                                 ...         ...      ...
# ...

# %%
eng_df = df[df["is_english"]==True]

# %%
eng_df
# Out:
#       Unnamed: 0          id  \
# 0              1   281656475
# 1              2   281796108
# 2              3   281940292
# 3              4   282614216
# 4              5   282935706
# ...          ...         ...
# 7192       11081  1187617475
# 7193       11082  1187682390
# 7194       11087  1187779532
# 7195       11089  1187838770
# 7196       11097  1188375727
#
#                                              track_name  size_bytes currency  \
# 0                                       PAC-MAN Premium   100788224      USD
# 1                             Evernote - stay organized   158578688      USD
# 2       WeatherBug - Local Weather, Radar, Maps, Alerts   100524032      USD
# 3     eBay: Best App to Buy, Sell, Save! Online Shop...   128512000      USD
# 4                                                 Bible    92774400      USD
# ...                                                 ...         ...      ...
# ...

# %%
print(eng_df)
# Out:
#       Unnamed: 0          id  \
# 0              1   281656475
# 1              2   281796108
# 2              3   281940292
# 3              4   282614216
# 4              5   282935706
# ...          ...         ...
# 7192       11081  1187617475
# 7193       11082  1187682390
# 7194       11087  1187779532
# 7195       11089  1187838770
# 7196       11097  1188375727
#
#                                              track_name  size_bytes currency  \
# 0                                       PAC-MAN Premium   100788224      USD
# 1                             Evernote - stay organized   158578688      USD
# 2       WeatherBug - Local Weather, Radar, Maps, Alerts   100524032      USD
# 3     eBay: Best App to Buy, Sell, Save! Online Shop...   128512000      USD
# 4                                                 Bible    92774400      USD
# ...                                                 ...         ...      ...
# ...

# %%
df[df.track_name.map(lambda x:x.isascii())]
# Out:
#       Unnamed: 0          id  \
# 0              1   281656475
# 1              2   281796108
# 2              3   281940292
# 3              4   282614216
# 4              5   282935706
# ...          ...         ...
# 7192       11081  1187617475
# 7193       11082  1187682390
# 7194       11087  1187779532
# 7195       11089  1187838770
# 7196       11097  1188375727
#
#                                              track_name  size_bytes currency  \
# 0                                       PAC-MAN Premium   100788224      USD
# 1                             Evernote - stay organized   158578688      USD
# 2       WeatherBug - Local Weather, Radar, Maps, Alerts   100524032      USD
# 3     eBay: Best App to Buy, Sell, Save! Online Shop...   128512000      USD
# 4                                                 Bible    92774400      USD
# ...                                                 ...         ...      ...
# ...
